# %% [markdown]
# # HOW TO USE DOCKER
# **2025 — Docker Tutorial**<br/>
# Lecturer: **Viet Nguyen AI**<br/>
# Student: **Luong Thanh Tuan**<br/>
# **Target: Know about Image, Containers in Docker .**<br/>

# %%
## How to run
-
